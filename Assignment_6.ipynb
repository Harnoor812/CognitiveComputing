# %%
import numpy as np
import pandas as pd

M = int(input())
x = np.linspace(-10, 10)
def y(x):
    return M * (x**2)

print(y(x))

def y1(x):
    return M * (np.sin(x))
print(y1(x))

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))  
plt.plot(x, y(x), label='y = M * x^2', color='blue', linestyle='-')
plt.plot(x, y1(x), label='y = M * sin(x)', color='red', linestyle='--')

plt.legend()
plt.grid(True)
plt.title('Plot of Two Functions')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
# Out:
#  10
# [1.00000000e+03 9.20033319e+02 8.43398584e+02 7.70095793e+02
#  7.00124948e+02 6.33486047e+02 5.70179092e+02 5.10204082e+02
#  4.53561016e+02 4.00249896e+02 3.50270721e+02 3.03623490e+02
#  2.60308205e+02 2.20324865e+02 1.83673469e+02 1.50354019e+02
#  1.20366514e+02 9.37109538e+01 7.03873386e+01 5.03956685e+01
#  3.37359434e+01 2.04081633e+01 1.04123282e+01 3.74843815e+00
#  4.16493128e-01 4.16493128e-01 3.74843815e+00 1.04123282e+01
#  2.04081633e+01 3.37359434e+01 5.03956685e+01 7.03873386e+01
#  9.37109538e+01 1.20366514e+02 1.50354019e+02 1.83673469e+02
#  2.20324865e+02 2.60308205e+02 3.03623490e+02 3.50270721e+02
#  4.00249896e+02 4.53561016e+02 5.10204082e+02 5.70179092e+02
#  6.33486047e+02 7.00124948e+02 7.70095793e+02 8.43398584e+02
#  9.20033319e+02 1.00000000e+03]
# [ 5.44021111  1.66282794 -2.38775316 -6.04603317 -8.71096703 -9.94471367
#  -9.544572   -7.57628415 -4.36323426 -0.43331733  3.56779241  6.98272396
#   9.25041372  9.99828668  9.10346944  6.71297794  3.21956315 -0.80281675
#  -4.69329613 -7.81268024 -9.64846309 -9.89903076 -8.5232157  -5.74706041
#  -2.02667937  2.02667937  5.74706041  8.5232157   9.89903076  9.64846309
#   7.81268024  4.69329613  0.80281675 -3.21956315 -6.71297794 -9.10346944
#  -9.99828668 -9.25041372 -6.98272396 -3.56779241  0.43331733  4.36323426
#   7.57628415  9.544572    9.94471367  8.71096703  6.04603317  2.38775316
#  -1.66282794 -5.44021111]

# %%
data = pd.DataFrame({"Subjects": ["Eng", "Math", "Sci", "S.S.T", " Hindi"],
        "Scores": [88, 100, 58, 20, 89]})

data.head()

import seaborn as sns
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="Subjects", y="Scores", data=data, palette="viridis")  # Use 'palette' for colors

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 9),
                textcoords='offset points')

plt.title("Scores in Different Subjects")
plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.grid(True)

plt.show()
# Out:
# C:\Users\harno\AppData\Local\Temp\ipykernel_20000\3397937067.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="Subjects", y="Scores", data=data, palette="viridis")  # Use 'palette' for colors

# %%
rno = int(input())
np.random.seed(rno)
dataset = np.random.randn(50)
fig, axes = plt.subplots(2,2,figsize = (10,8))

axes[0, 0].plot(np.cumsum(dataset),marker ="o", linestyle="-")
axes[0, 0].set_title('Cumulative Sum')
axes[0, 0].set_xlabel('Data Point')
axes[0, 0].set_ylabel('Cumulative Sum')
axes[0, 0].grid(True)

noise = np.random.randn(50) * 0.2
axes[1, 1].scatter(dataset, dataset + noise, marker='x', color='red')
axes[1, 1].set_title('Scatter Plot with Random Noise')
axes[1, 1].set_xlabel('X-axis')
axes[1, 1].set_ylabel('Y-axis')
axes[1, 1].grid(True)

plt.show()
# Out:
#  102317138

# %%
df = pd.read_csv("C:/Users/harno/Downloads/company_sales_data.csv")
df.head()

fig, axes = plt.subplots(2,2,figsize = (10,8))
sns.lineplot(x="month_number", y ="total_profit",data=df, palette="viridis",ax = axes[0,0])
axes[0,0].set_title("Total_profit for all months")
axes[0,0].set_xlabel("Month number")
axes[0,0].set_ylabel("Total_profit")
axes[0,0].grid(True)

products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
for product in products:
    sns.lineplot(x='month_number', y=product, data=df, label=product, ax = axes[0,1])
plt.legend()
plt.show()
axes[0,1].set_title("Product Sales Data")
axes[0,1].set_xlabel("Month number")
axes[0,1].set_ylabel("Sales")
axes[0,1].grid(True)

plt.show()

plt.figure(figsize=(16, 5))
df.drop(columns='month_number').sum().plot(kind='bar')
plt.title('Bar Chart for All Features/Attributes')
plt.xlabel('Features')
plt.ylabel('Value')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\harno\AppData\Local\Temp\ipykernel_20000\2730892120.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x="month_number", y ="total_profit",data=df, palette="viridis",ax = axes[0,0])
# C:\Users\harno\AppData\Local\Temp\ipykernel_20000\2730892120.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
