# %%
import numpy as np

# %% [markdown]
# **Ques 1**

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
print('Sum of all elements',gfg.sum())
print('Sum of elements row wise',np.sum(gfg,axis=1))
print('Sum of elements column wise',np.sum(gfg,axis=0))
# Out:
# Sum of all elements 45
# Sum of elements row wise [[14]
#  [16]
#  [15]]
# Sum of elements column wise [[20  9 16]]

# %% [markdown]
# **Ques 2(a)**

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])
sort_array=np.sort(array)
print('Sorted array :',sort_array)
print('Indices of sorted array :',np.argsort(array))
print('4 smallest elements',sort_array[:4])
print('5 smallest elements',sort_array[-5:])
# Out:
# Sorted array : [ 10  16  16  52  54  62 453]
# Indices of sorted array : [0 3 4 1 5 2 6]
# 4 smallest elements [10 16 16 52]
# 5 smallest elements [ 16  52  54  62 453]

# %% [markdown]
# **Ques 2(b)**

# %%
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
int_elements = array[array == np.floor(array)]
print('Integer elements :',int_elements)
float_elements = array[array != np.floor(array)]
print('Float elements :',float_elements)
# Out:
# Integer elements : [1. 2. 3. 2.]
# Float elements : [1.2 2.2]

# %% [markdown]
# **Ques 3(a)**

# %%
# Name -> Harnoor Kaur
X= ord('H')+ ord('K')
sales= np.array([X, X+50, X+100, X+150, X+200])
print(sales)
# Out:
# [147 197 247 297 347]

# %% [markdown]
# **Ques 3(b)**

# %%
tax_rate= ((X % 5)+5)/100
tax_sales= (tax_rate+1)*sales
print(tax_sales)
# Out:
# [157.29 210.79 264.29 317.79 371.29]

# %% [markdown]
# **Ques 3(c)**

# %%
discount_sales= np.where(sales<X+100, sales-sales*0.05, sales-sales*0.10)
print(discount_sales)
# Out:
# [139.65 187.15 222.3  267.3  312.3 ]

# %% [markdown]
# **Ques 3(d)**

# %%
week_sales= np.tile(sales,(3,1))
print('Broadcasted sales array :',week_sales)
weeks=np.arange(3)           #to separate rows
print('\n')
inc_sales=  week_sales * (1.02** weeks[:,np.newaxis])
print('Increased sales :\n',inc_sales)
# Out:
# Broadcasted sales array : [[147 197 247 297 347]
#  [147 197 247 297 347]
#  [147 197 247 297 347]]
#
#
# Increased sales :
#  [[147.     197.     247.     297.     347.    ]
#  [149.94   200.94   251.94   302.94   353.94  ]
#  [152.9388 204.9588 256.9788 308.9988 361.0188]]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Ques 4**

# %%
x = np.linspace(-10,10, num=100)
y = x**2
plt.plot(x,y, marker=".")
plt.title("Y = X^2")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.grid()
plt.show()

# %%
y = np.sin(x)
plt.plot(x,y, marker=".", color='r')
plt.title("Y = sin(X)")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.grid()
plt.show()

# %%
y = np.exp(x)
plt.plot(x,y, marker=".",color='g')
plt.title("Y = e^(X)")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.grid()
plt.show()

# %%
y = np.log(np.abs(x)+1)
plt.plot(x,y, marker=".",color='y')
plt.title("Y = log(|X|+1)")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.grid()
plt.show()
